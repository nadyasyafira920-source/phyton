# %% [markdown]
# <a href="https://colab.research.google.com/github/nadyasyafira920-source/phyton/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = input("Masukkan nama: ")  # Meminta pengguna memasukkan nama
nilai = float(input("Masukkan nilai: "))  # Meminta nilai dan mengubahnya menjadi tipe float

print("Nama :", nama)  # Menampilkan nama yang sudah dimasukkan
print("Nilai :", nilai)  # Menampilkan nilai yang sudah dimasukkan
